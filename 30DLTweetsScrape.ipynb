# %% [markdown]
# # Twitter Hashtag Analysis
# ### #NG30DaysofLearning

# %% [markdown]
# ## Data Gathering

# %%
# installing snscrape
# !pip install --upgrade snscrape
# Out:
# Requirement already satisfied: snscrape in c:\users\iyes\anaconda3\lib\site-packages (0.6.2.20230320)
# Requirement already satisfied: filelock in c:\users\iyes\anaconda3\lib\site-packages (from snscrape) (3.6.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\iyes\anaconda3\lib\site-packages (from snscrape) (4.11.1)
# Requirement already satisfied: lxml in c:\users\iyes\anaconda3\lib\site-packages (from snscrape) (4.8.0)
# Requirement already satisfied: requests[socks] in c:\users\iyes\anaconda3\lib\site-packages (from snscrape) (2.27.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\iyes\anaconda3\lib\site-packages (from beautifulsoup4->snscrape) (2.3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\iyes\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\iyes\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\iyes\anaconda3\lib\site-packages (from requests[socks]->snscrape) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\iyes\anaconda3\lib\site-packages (from requests[socks]->snscrape) (3.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\iyes\anaconda3\lib\site-packages (from requests[socks]->snscrape) (1.7.1)

# %%
# importing needed libraries
import pandas as pd
import snscrape.modules.twitter as sntwitter
from textblob import TextBlob

# %%
# scrape using snscrape
query = "(#30DaysOfLearning OR #NG30DaysOfLearning) until:2022-07-01 since:2022-05-01"
tweets = []
limit = 30000


for tweet in sntwitter.TwitterHashtagScraper(query).get_items():
    
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.url, tweet.user.username, tweet.sourceLabel, tweet.user.location, tweet.content, 
                       tweet.likeCount, tweet.retweetCount,  tweet.quoteCount, tweet.replyCount])
        
df = pd.DataFrame(tweets, columns=['Date', 'TweetURL','User', 'Source', 'Location', 'Tweet', 'Likes_Count','Retweet_Count', 
                                   'Quote_Count', 'Reply_Count'])

# read dataframe to csv
df.to_csv('30DLTweets.csv')

# %% [markdown]
# ## Data Assessment

# %% [markdown]
# ### Visual Assessment

# %%
# read the csv file into a pandas dataframe
data = pd.read_csv('30DLTweets.csv')

# first five hashtag tweets
data
# Out:
#      Unnamed: 0                       Date  \
# 0             0  2022-06-30 23:41:31+00:00
# 1             1  2022-06-30 23:02:00+00:00
# 2             2  2022-06-30 22:49:03+00:00
# 3             3  2022-06-30 22:44:02+00:00
# 4             4  2022-06-30 21:49:16+00:00
# ..          ...                        ...
# 785         785  2022-05-10 17:30:02+00:00
# 786         786  2022-05-10 08:26:54+00:00
# 787         787  2022-05-09 17:11:34+00:00
# 788         788  2022-05-09 16:00:25+00:00
# 789         789  2022-05-04 09:48:14+00:00
#
#                                               TweetURL             User  \
# 0    https://twitter.com/Oloko_Burn_Fire/status/154...  Oloko_Burn_Fire
# 1    https://twitter.com/bossking_uee/status/154264...     bossking_uee
# 2    https://twitter.com/bossking_uee/status/154264...     bossking_uee
# 3    https://twitter.com/Fabulousnani01/status/1542...   Fabulousnani01
# 4    https://twitter.com/debunmiT/status/1542626348...         debunmiT
# ..                                                 ...              ...
# 785  https://twitter.com/TheOyinbooke/status/152407...     TheOyinbooke
# 786  https://twitter.com/LibraryImpactNG/status/152...  LibraryImpactNG
# 787  https://twitter.com/TheOyinbooke/status/152371...     TheOyinbooke
# 788  https://twitter.com/TheOyinbooke/status/152369...     TheOyinbooke
# 789  https://twitter.com/0xRh1d0Y/status/1521788785...         0xRh1d0Y
#
#                   Source         Location  \
# 0    Twitter for Android   school of Life
# 1     Twitter for iPhone   Lagos, Nigeria
# 2     Twitter for iPhone   Lagos, Nigeria
# 3    Twitter for Android              NaN
# 4    Twitter for Android              NaN
# ..                   ...              ...
# 785  Twitter for Android           Global
# 786  Twitter for Android  Lagos, Nigeria.
# 787  Twitter for Android           Global
# 788  Twitter for Android           Global
# 789      Twitter Web App       Bangladesh
#
#                                                  Tweet  Likes_Count  \
# 0    **********July 2022**********\n- Tailwind CSS‼...            5
# 1    You quit, you lose. You keep going, you you ma...            0
# 2                     Data Analysis\n#30daysoflearning            0
# 3    Tomorrow's Session on #30daysoflearning is on ...            2
# 4    To everyone involved in this I want to say a b...          136
# ..                                                 ...          ...
# 785  I love playing football but you know what is m...           27
# 786  Why not join the #NG30daysofLearning while wai...            0
# 787  Since I read the ASUU Strike announcement, I h...          137
# 788  April 2022, @DavidAbu_, @japhletnwamu, @Cinnam...           88
# 789  I'll be doing 30 days of Bug Bounty learning a...            5
#
#      Retweet_Count  Quote_Count  Reply_Count
# 0                2            1            2
# 1                0            0            0
# 2                0            0            0
# 3                0            0            0
# 4                8            0           15
# ..             ...          ...          ...
# 785              9            0            1
# 786              0            0            0
# 787             40            1            9
# 788             47            3            6
# 789              0            0            1
#
# [790 rows x 11 columns]

# %% [markdown]
# ### Programmatic Assessment

# %%
data.shape
# Out:
# (790, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 790 entries, 0 to 789
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     790 non-null    int64
#  1   Date           790 non-null    object
#  2   TweetURL       790 non-null    object
#  3   User           790 non-null    object
#  4   Source         790 non-null    object
#  5   Location       627 non-null    object
#  6   Tweet          790 non-null    object
#  7   Likes_Count    790 non-null    int64
#  8   Retweet_Count  790 non-null    int64
#  9   Quote_Count    790 non-null    int64
#  10  Reply_Count    790 non-null    int64
# dtypes: int64(5), object(6)
# memory usage: 68.0+ KB

# %%
data.nunique()
# Out:
# Unnamed: 0       790
# Date             789
# TweetURL         790
# User             222
# Source             6
# Location          93
# Tweet            787
# Likes_Count      108
# Retweet_Count     44
# Quote_Count        8
# Reply_Count       20
# dtype: int64

# %%
# statistical summary
data.describe()
# Out:
#        Unnamed: 0  Likes_Count  Retweet_Count  Quote_Count  Reply_Count
# count  790.000000    790.00000     790.000000   790.000000   790.000000
# mean   394.500000     17.55443       3.924051     0.192405     1.264557
# std    228.197648     48.85940      12.994756     0.750795     2.999727
# min      0.000000      0.00000       0.000000     0.000000     0.000000
# 25%    197.250000      1.00000       0.000000     0.000000     0.000000
# 50%    394.500000      2.00000       0.000000     0.000000     0.000000
# 75%    591.750000     10.00000       2.000000     0.000000     1.000000
# max    789.000000    604.00000     272.000000    10.000000    38.000000

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# Date               0
# TweetURL           0
# User               0
# Source             0
# Location         163
# Tweet              0
# Likes_Count        0
# Retweet_Count      0
# Quote_Count        0
# Reply_Count        0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Data Preprocessing

# %%
# define a function to perform sentiment analysis on a single tweet
def analyze(tweet):
    blob = TextBlob(tweet)
    return blob.sentiment.polarity

# apply the analyze function to each tweet in the dataframe and store the results in a new column
data['sentiment_score'] = data['Tweet'].apply(analyze)

# %%
# output the results
data.sample(5)
# Out:
#      Unnamed: 0                       Date  \
# 569         569  2022-06-12 19:21:00+00:00
# 109         109  2022-06-26 21:19:03+00:00
# 721         721  2022-06-08 10:53:31+00:00
# 381         381  2022-06-17 09:15:17+00:00
# 404         404  2022-06-16 11:13:50+00:00
#
#                                               TweetURL            User  \
# 569  https://twitter.com/_JosiahAdesola/status/1536...  _JosiahAdesola
# 109  https://twitter.com/TheOyinbooke/status/154116...    TheOyinbooke
# 721  https://twitter.com/d_adetunji/status/15344887...      d_adetunji
# 381  https://twitter.com/Phatergh/status/1537725560...        Phatergh
# 404  https://twitter.com/ZionDoz/status/15373930039...         ZionDoz
#
#                   Source         Location  \
# 569      Twitter Web App   Lagos, Nigeria
# 109  Twitter for Android           Global
# 721      Twitter Web App  Ibadan, Nigeria
# 381  Twitter for Android        Metaverse
# 404  Twitter for Android                🌏
#
#                                                  Tweet  Likes_Count  \
# 569  Access to Microsoft 365 full package, freebies...            8
# 109  I know you are not sleeping so, take 5secs to ...           45
# 721  It was a great session yesterday with @TheOyin...            6
# 381  #30daysoflearning \n#DataAnalytics \nRecap of ...            6
# 404  Day 1 of #NG30DaysOfLearning\n-Start with Valu...           12
#
#      Retweet_Count  Quote_Count  Reply_Count  sentiment_score
# 569              0            0            0          0.28750
# 109             13            0            4          0.51250
# 721              0            0            0          0.80000
# 381              1            0            1          0.30625
# 404              3            0            1          0.00000

# %%
# define a function to group score based sentiment
def grade(score):
    if score > 0:
        return 'Positive'
    elif score < 0:
        return 'Negative'
    else:
        return 'Neutral'

# apply the grade function to the sentiment_score column and store the results in a new column
data['sentiment'] = data['sentiment_score'].apply(grade)

# %%
# output the results
data.sample(5)
# Out:
#      Unnamed: 0                       Date  \
# 212         212  2022-06-22 20:44:44+00:00
# 34           34  2022-06-29 15:57:34+00:00
# 12           12  2022-06-30 17:06:02+00:00
# 35           35  2022-06-29 14:49:02+00:00
# 263         263  2022-06-21 13:21:49+00:00
#
#                                               TweetURL            User  \
# 212  https://twitter.com/ladun331/status/1539711002...        ladun331
# 34   https://twitter.com/unstoppable_tp/status/1542...  unstoppable_tp
# 12   https://twitter.com/ruc_thakkar/status/1542555...     ruc_thakkar
# 35   https://twitter.com/TheOyinbooke/status/154215...    TheOyinbooke
# 263  https://twitter.com/KingOlisa/status/153923715...       KingOlisa
#
#                   Source               Location  \
# 212   Twitter for iPhone         Lagos, Nigeria
# 34   Twitter for Android         Ekiti, Nigeria
# 12       Twitter Web App  Ahmadabad City, India
# 35   Twitter for Android                 Global
# 263  Twitter for Android         Lagos, Nigeria
#
#                                                  Tweet  Likes_Count  \
# 212  I created this dashboard in powerBI to show th...            6
# 34   @TheOyinbooke #NG30DaysOfLearning \n#30daysofl...            0
# 12   Day 12 of #30daysofcode\n\nCompleted remaining...            5
# 35   Unsupervised Machine Learning in Action💻 🔥\nCl...           24
# 263  Week 2 Built a dashboard on Excel analysing CO...            1
#
#      Retweet_Count  Quote_Count  Reply_Count  sentiment_score sentiment
# 212              2            0            3              0.0   Neutral
# 34               0            0            0              0.0   Neutral
# 12               6            0            1              0.0   Neutral
# 35               2            0            1             -0.4  Negative
# 263              1            0            0              0.0   Neutral

# %%
data.to_csv('30DLTweets.csv')
